# %% [markdown]
# # Notebook für SDM Analyse

# %% [markdown]
# ## Load packages

# %%
# import standard packages
from datetime import date, datetime
import time
import math
import json
import io
from pathlib import Path
import zipfile

import ee
# import fiona
# import geemap #.foliumap as geemap
# import geemap.foliumap as folium
# import geemap.colormaps as cm
# import geopandas as gpd
# import matplotlib.pyplot as plt
# import matplotlib as mpl

# import numpy as np


from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import pandas as pd
from pygbif import species as species
from pygbif import occurrences as occ

# import rioxarray as rxr
# import xarray as xr
# import leafmap



from toolbox.utils import *
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
status = occ.download_meta("0013960-260226173443078")
status
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'key': '0013960-260226173443078',
#  'doi': '10.15468/dl.c4bdnw',
#  'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#  'request': {'sql': '\nSELECT species, decimalLatitude as lat, decimalLongitude as lon, "year"\nFROM occurrence\nWHERE basisOfRecord = \'HUMAN_OBSERVATION\'\nAND hasCoordinate = TRUE\nAND countryCode = \'AT\'\nAND species IS NOT NULL\nAND decimalLatitude IS NOT NULL\nAND decimalLongitude IS NOT NULL\n',
#   'sendNotification': True,
#   'format': 'SQL_TSV_ZIP',
#   'type': 'OCCURRENCE'},
#  'created': '2026-03-04T21:06:45.887+00:00',
#  'modified': '2026-03-04T21:35:14.154+00:00',
#  'eraseAfter': '2026-09-04T21:06:45.851+00:00',
#  'status': 'SUCCEEDED',
#  'downloadLink': 'https://api.gbif.org/v1/occurrence/download/request/0013960-260226173443078.zip',
#  'size': 375101276,
#  'totalRecords': 13157048,
#  'numberDatasets': 162}

# %%
response = requests.get('https://api.gbif.org/v1/occurrence/download/request/0013960-260226173443078.zip')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
with zipfile.ZipFile(io.BytesIO(response.content)) as zf:
        csv_name = next((n for n in zf.namelist() if n.endswith(".csv")), None)
        if csv_name is None:
            raise ValueError("No CSV file found in archive")

        with zf.open(csv_name) as csv_file:
            df = pd.read_csv(csv_file, sep='\t', low_memory=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
b = "b.csv"

b.endswith(".tsv") or b.endswith(".csv")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
all_records = []
offset = 0
limit = 300  # Max per API call

while True:
    result = occ.search(
        datasetKey='0013891-260226173443078',
        limit=limit,
        offset=offset,
        hasCoordinate=True
    )

    records = result.get("results", [])
    if not records:
        break

    all_records.extend(records)

    # Check if there are more records
    if len(records) < limit:
        break

    offset += limit
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 limit = 300  # Max per API call
#       5 while True:
# ----> 6     result = occ.search(
#       7         datasetKey='0013891-260226173443078',
#       8         limit=limit,
#       9         offset=offset,
#      10         hasCoordinate=True
#      11     )
#      13     records = result.get("results", [])
#      14     if not records:
#
# File ~/Documents/masterarbeit/ma_code/toolbox/.venv/lib/python3.12/site-packages/pygbif/occurrences/search.py:408, in search(taxonKey, repatriated, kingdomKey, phylumKey, classKey, orderKey, familyKey, genusKey, subgenusKey, scientificName, country, publishingCountry, hasCoordinate, typeStatus, recordNumber, lastInterpreted, continent, geometry, recordedBy, recordedByID, identifiedByID, basisOfRecord, datasetKey, eventDate, catalogNumber, year, month, decimalLatitude, decimalLongitude, elevation, depth, institutionCode, collectionCode, hasGeospatialIssue, issue, q, spellCheck, mediatype, limit, offset, establishmentMeans, facet, facetMincount, facetMultiselect, **kwargs)
#     406     args.update(xx)
#     407 kwargs = {key: kwargs[key] for key in kwargs if key in requests_argset}
# --> 408 out = gbif_GET(url, args, **kwargs)
#     409 return out
#
# File ~/Documents/masterarbeit/ma_code/toolbox/.venv/lib/python3.12/site-packages/pygbif/gbifutils.py:34, in gbif_GET(url, args, **kwargs)
#      32 def gbif_GET(url, args, **kwargs):
#      33     out = requests.get(url, params=args, headers=make_ua(), **kwargs)
# ---> 34     out.raise_for_status()
#      35     stopifnot(out.headers["content-type"])
#      36     return out.json()
#
# File ~/Documents/masterarbeit/ma_code/toolbox/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.gbif.org/v1/occurrence/search?hasCoordinate=true&datasetKey=0013891-260226173443078&limit=300&offset=0

# %% [markdown]
# ## GEE Auth

# %%
ee.Authenticate()
# enter your project id here
# check google on how to set up a project
ee.Initialize(project='ee-sebasd1991')

with open('.secrets.json', 'r') as f:
    auth = json.load(f).get('GBIF')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Parameter setup

# %%
year = 2024

country_code = 'AT'
county_name = 'Tirol'

species_name = 'Lagopus muta'

limit = 2000  # for sql query.

selected_features = ['landcover', 'CHM', 'b1', 'b12', 'elevation', 'NARI', 'NCRI', 'GHMI']  # Many features might increase overfitting and take longer to retrieve from gee
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
country, county = get_aoi_from_nuts(country_code='AT', county_name='Tirol')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO:Created 1 records
# INFO:Created 1 records

# %% [markdown]
# ## Get species Presence Points

# %%
sql=f"""
SELECT species, \"year\", decimalLongitude as long, decimalLatitude as lat
FROM occurrence
WHERE countryCode = '{country_code}'
AND species = '{species_name}'
AND \"year\" >= 2024
AND hasCoordinate = TRUE
AND basisOfRecord = 'HUMAN_OBSERVATION'
LIMIT {limit}
"""
print(sql)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# SELECT species, "year", decimalLongitude as long, decimalLatitude as lat
# FROM occurrence
# WHERE countryCode = 'AT'
# AND species = 'Lagopus muta'
# AND "year" >= 2024
# AND hasCoordinate = TRUE
# AND basisOfRecord = 'HUMAN_OBSERVATION'
# LIMIT 2000

# %%
response = occ.download_sql(sql=sql, user=auth["username"], pwd=auth["password"], email=auth["email"])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO:Your sql download key is 0009286-260208012135463

# %%
response = '0015176-260108223611665'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
status_url = f"https://api.gbif.org/v1/occurrence/download/{response}"
print("Current time: ", time.strftime("%H:%M:%S"))
while True:
    r = requests.get(status_url, auth=(auth["username"], auth["password"]))
    data = r.json()
    status = data.get('status')
    if status == 'SUCCEEDED':
        print("Download ready!")
        download_url = f"https://api.gbif.org/v1/occurrence/download/request/{response}.zip"
        zip_path = f"assets/gbif_{species_name.replace(' ', '_')}.zip"
        with requests.get(download_url, auth=(auth["username"], auth["password"]), stream=True) as r:
            with open(zip_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        print(f"Download saved as {zip_path}")
        break
    elif status in ['KILLED', 'FAILED']:
        raise Exception(f" ❌ Download failed: {species_name}")
    else:
        print("Waiting for download to complete... ☕")
        time.sleep(60)
print(" ✅ Finishing time: ", time.strftime("%H:%M:%S"))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Current time:  22:26:51
# Download ready!
# Download saved as assets/gbif_Lagopus_muta.zip
#  ✅ Finishing time:  22:26:52

# %%
with zipfile.ZipFile(zip_path, 'r') as z:
    with z.open(f"{response}.csv") as f:
        species_df = pd.read_csv(f, sep='\t', low_memory=False)
species_df = species_df.dropna(subset=['long', 'lat'])
species_df = gpd.GeoDataFrame(species_df,
                              geometry=gpd.points_from_xy(species_df['long'], species_df['lat']),
                              crs='EPSG:4326')
species_ee = geemap.gdf_to_ee(species_df)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO:Created 849 records

# %% [markdown]
# ## Load all prediction layer

# %%
# WorldClim Bioclim
try:
    bioclim = ee.Image("projects/ee-sebasd1991/assets/BioClim")
except:
    print("Bioclim asset not found, loading history data from pubic source.")
    bioclim = ee.Image("WORLDCLIM/V1/BIO")

# NASA SRTM Digital Elevation 30m
terrain = ee.Algorithms.Terrain(ee.Image("USGS/SRTMGL1_003"))
northness = terrain.select('aspect').multiply(math.pi/180).cos().rename('northness')
eastness = terrain.select('aspect').multiply(math.pi/180).sin().rename('eastness')

# NDVI
NDVI = (
    ee.ImageCollection('LANDSAT/COMPOSITES/C02/T1_L2_8DAY_NDVI')
    .filterDate(f'{year}-01-01', f'{year + 1}-01-01')
    .mean()
).rename('NDVI')

HM_300M = ee.ImageCollection("projects/sat-io/open-datasets/GHM/HM_2022_300M").first().rename('GHMI')

era5 = (ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')
        .filter(ee.Filter.date(f'{year}-01-01', f'{year + 1}-01-01'))
)
swe = era5.select(['snow_depth_water_equivalent'], ['SWE']).mean()
snow_depth = era5.select(['snow_depth'], ['snow_depth']).mean()
snow_cover = era5.select(['snow_cover'], ['snow_cover']).mean()
snow_albedo = era5.select(['snow_albedo'], ['snow_albedo']).mean()

#CLC
landcover = ee.Image("COPERNICUS/CORINE/V20/100m/2018").select('landcover')
canopyHeight = ee.ImageCollection("projects/sat-io/open-datasets/facebook/meta-canopy-height").mosaic().rename('CHM');

nari = gee_calculate_scrub_index('nari', year).rename('NARI')
ncri = gee_calculate_scrub_index('ncri', year).rename('NCRI')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Combine bands into a multi-band image
predictors = landcover.addBands(northness).addBands(eastness).addBands(NDVI).addBands(swe).addBands(snow_cover).addBands(snow_depth).addBands(terrain.select(['elevation', 'aspect', 'slope'])).addBands(canopyHeight).addBands(nari).addBands(ncri).addBands(HM_300M).addBands(bioclim)

# Create a water mask
watermask = terrain.select('elevation').gt(0)

# Mask out ocean pixels and clip to the area of interest
predictors = predictors.updateMask(watermask).clip(country)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
background_data = load_background_data()
presence_data, predictors = get_species_features(species_df, selected_features, get_layer_information(year))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO:Created 849 records

# %%
model = 'Embedding'  # Maxent, Embedding
n_trees  = 500
tree_depth = 5
train_size = .85
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
model, results_df, ml_gdf = compute_sdm(
                                presence=presence_data,
                                background=background_data,
                                features=list(selected_features),
                                model_type=model,
                                n_trees=n_trees,
                                tree_depth=tree_depth,
                                train_size=train_size,
                                )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
classified_img_pr = classify_image_aoi(
                            image=predictors,
                            aoi=county,
                            ml_gdf=ml_gdf,
                            model=model,
                            features=list(selected_features)
                        )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO:Created 1,644 records
# INFO:Created 1,644 records

# %%
results_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Show map

# %%
Map = geemap.Map()
Map.add_basemap("SATELLITE")

Map.addLayer(classified_img_pr, {'min': 0, 'max': 1, 'palette': geemap.colormaps.palettes.viridis_r}, 'Classified Image', opacity=.7)
Map.addLayer(species_ee, {'color':'red'}, 'POI')
Map.add_colorbar({'min': 0, 'max': 1, 'palette': geemap.colormaps.palettes.viridis_r}, label="Habitat suitability",
                orientation="horizontal",
                position="bottomright",
                layer_name="Habitat suitability")
Map.centerObject(country)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# ## Various summary stats

# %%
threshold= classified_img_pr.reduceRegion(
    reducer=ee.Reducer.percentile([10]),
    geometry=species_ee,
    scale=30,
    maxPixels=1e13
).getInfo()['classification']
print(threshold)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0.6936281888402989

# %%
(classified_img_pr.gte(threshold)).reduceRegion(
    reducer=ee.Reducer.mean(),
    geometry=county,
    scale=30,
    maxPixels=1e13
).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'classification': 0.4242135265147319}

# %%
canopyHeight.reduceRegion(
    reducer=ee.Reducer.median(),
    geometry=species_ee,
    scale=30,
    maxPixels=1e13
).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'CHM': 0}

# %%
terrain.select('elevation').updateMask(classified_img_pr.gte(threshold)).reduceRegion(
    reducer=ee.Reducer.mean(),
    geometry=county,
    scale=30,
    maxPixels=1e13
).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'elevation': 2335.53899852467}

# %% [markdown]
# ## Export classified image

# %%
task = ee.batch.Export.image.toDrive(
    image = classified_img_pr,
    description=f'sdm_{species_name.replace(' ', '_')}_{county_name}_{datetime.now().date().strftime("%Y_%m_%d")}',
    # assetId='projects/ee-sebasd1991/assets/sdm/sdm_rf_20251220_1',
    scale=10,
    region=county.geometry().bounds(),
    fileFormat='GeoTIFF',
    crs='EPSG:3857',
    maxPixels=1e13,
    formatOptions={'noData': 0},

)
task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
while True:
    status = task.status()['state']
    match status:
        case 'RUNNING':
            print('Still running ... ☕')
            time.sleep(60)
        case 'COMPLETE':
            print(' ✅ Check your Google - Drive')
            break
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# Still running ... ☕
# WARNING:Sleeping 1.60 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 1.05 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 0.16 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 1.02 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 0.56 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 1.52 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 0.66 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 1.28 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503
# WARNING:Sleeping 0.19 seconds before retry 1 of 5 for request: GET https://earthengine.googleapis.com/v1/projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ?alt=json, after 503

# %%
task.status()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'state': 'RUNNING',
#  'description': 'sdm_Lagopus_muta_Tirol_2026_01_16',
#  'priority': 100,
#  'creation_timestamp_ms': 1768594033292,
#  'update_timestamp_ms': 1768594151635,
#  'start_timestamp_ms': 1768594047850,
#  'task_type': 'EXPORT_IMAGE',
#  'attempt': 1,
#  'id': 'F6QNDXXJKYGLY4OJSMIBBLGJ',
#  'name': 'projects/ee-sebasd1991/operations/F6QNDXXJKYGLY4OJSMIBBLGJ'}
